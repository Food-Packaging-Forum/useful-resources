# %% [markdown]
# # Generate EndNote-Compatible .txt File
#
# This Jupyter Notebook contains a Python function named `generate_endnote_txt_file()` that takes a DataFrame with citation information and generates an EndNote-compatible .txt file. The function formats the provided data according to EndNote's requirements for importing references and writes the formatted entries to the specified output file.
#
# **Author: Lindsey V. Parkinson
# Date: August 23, 2023**
#
# ## Function Description
#
# The `generate_endnote_txt_file()` function performs the following steps:
#
# 1. **Input Parameters:**
#     - `dataframe`: A pandas DataFrame containing citation data, with columns representing different fields like author names, article titles, journal names, publication years, DOIs, etc.
#     - `output_file`: The desired output file path a/o name for the EndNote-compatible .txt file.
#
# 2. **Processing:**
#     - The function iterates through each row in the DataFrame and constructs formatted lines for each reference.
#     - It includes fields such as author names, article titles, journal names, publication years, and DOIs, following EndNote's field conventions.
#
# 3. **Formatting:**
#     - The formatted lines include the `%` field identifiers used by EndNote to distinguish and organize different components of a reference.
#     - You can customize the formatting and fields as needed, such as adding URLs, keywords, abstracts, or notes.
#     - EndNote field codes include:
#             %0: Reference Type (e.g., Journal Article, Book, Conference Paper, etc.)
#             %A: Author Names
#             %B: Series Title
#             %C: Place Published
#             %D: Year
#             %E: Editor Names
#             %F: Label
#             %G: Language
#             %H: Translated Author Names
#             %I: Publisher
#             %J: Journal Name
#             %K: Keywords
#             %L: Call Number
#             %M: Accession Number
#             %N: Notes
#             %O: Research Notes
#             %P: Pages
#             %Q: Translated Title
#             %R: DOI (Document Object Identifier)
#             %S: Short Title
#             %T: Title
#             %U: URL
#             %V: Volume
#             %W: Database Provider
#             %X: Abstract
#             %Y: Secondary Title (e.g., Journal Name for Book Chapter)
#             %Z: Custom 1
#             %1 to %9: User-Defined Fields 1 to 9
#
# 4. **Output:**
#     - The function writes the formatted references to the specified output file in the form of an EndNote-compatible .txt file.
#
#
#
# ## Usage Example
#
# To use the function, provide a DataFrame containing citation data and specify the desired output file name. For example:
#
# ```python
# generate_endnote_txt_file(df, 'endnote_all_excelrefs.txt')

# %%
import pandas as pd
import os
pd.options.display.max_columns = None

# %%
# working_directory = os.getcwd()

PFAS_excel = pd.read_csv( ...insert file path...  "\\PFAS_detected_47references.csv")

# our dataframe contains columns: [Title, Authors, Journal, Year, DOI]
# 
# example = {
#     "Title": [
#         "A forensic approach for distinguishing PFAS ma...",
#         "An optimized method for the determination of p..."
#     ],
#     "Authors": [
#         "Benotti, M. J.; Fernandez, L. A.; Peaslee, G. ...",
#         "Dolman, Sebastiaan; Pelzing, Matthias"
#     ],
#     "Journal": [
#         "Environmental Forensics",
#         "Journal of Chromatography B"
#     ],
#     "Year": [2020, 2011],
#     "DOI": [
#         "https://doi.org/10.1080/15275922.2020.1771631",
#         "https://doi.org/10.1016/j.jchromb.2011.05.032"
#     ]
# }

# # Create DataFrame
# df = pd.DataFrame(example)

# print(df)

# %%
PFAS_excel.head()
# Out:
#                                                 Title  \
# 0   A forensic approach for distinguishing PFAS ma...
# 1   An optimized method for the determination of p...
# 2   Assessment of the migration of perfluorinated ...
# 3   Chinese Cooking with Ionic Seasonings May Enha...
# 4   Comprehensive analysis of photoinitiators and ...
# 5   Concentrations and trends of perfluorinated ch...
# 6   Contaminants in the paper-based food packaging...
# 7   Data on migration of poly-and perfluorinated c...
# 8   Determination of Bisphenols and Related Compou...
# 9   Determination of perfluorinated alkyl acids in...
# 10  Determination of perfluorinated compounds (PFC...
# 11  Determination of perfluoroalkyl substances in ...
# 12  Determination of perfluorocompounds in popcorn...
# 13  Determination of perfluorooctane sulfonate and...
# 14  Determination of Selected Perfluorinated Acids...
# 15  Dispersive solid-phase extraction of bisphenol...
# 16  Emission of perfluoroalkyl carboxylic acids (P...
# 17  EXPOSURE TO THE PERSISTENT PERFLUORINATED COMP...
# 18  Extraction procedure optimization for perfluor...
# 19  Fast and simple determination of perfluorinate...
# 20  Fluorinated Compounds in U.S. Fast Food Packaging
# 21  Gas Purge Microsyringe Extraction Coupled with...
# 22  How Do We Measure Poly- and Perfluoroalkyl Sub...
# 23  Impact of Industrial Production and Packaging ...
# 24  Investigation of the migration of bisphenols f...
# 25  Is the use of paper food contact materials tre...
# 26  Machine learning directed discrimination of vi...
# 27  Method for analysis of 68 organic contaminants...
# 28  Migration of fluorinated Telomer alcohols (FTO...
# 29  Migration of fluorochemical paper additives fr...
# 30  Migration of perfluoroalkyl acids from food pa...
# 31  Molecularly imprinted solid-phase extraction f...
# 32  Novel computer-assisted separation prediction ...
# 33  Occurrence of per- and polyfluorinated compoun...
# 34  Perfluorinated compounds in food simulants aft...
# 35  Perfluoroalkyl and polyfluoroalkyl substances ...
# 36  Perfluorochemicals: potential sources of and m...
# 37  PFOA and PFOS levels in microwave paper packag...
# 38  Poly- and perfluoroalkyl substances (PFASs) in...
# 39  Polyfluoroalkyl phosphate esters and perfluoro...
# 40  Screening and identification of per- and polyf...
# 41  Simultaneous enrichment of bisphenols and poly...
# 42  Suspect Screening of Chemicals in Food Packagi...
# 43  The last straw: Characterization of per- and p...
# 44  Total Fluorine Measurements in Food Packaging:...
# 45  Twenty bisphenol analogues in take-out polysty...
# 46  Ubiquitous Occurrence of Fluorotelomer Alcohol...
#
#                                               Authors  \
# 0   Benotti, M. J.; Fernandez, L. A.; Peaslee, G. ...
# 1               Dolman, Sebastiaan; Pelzing, Matthias
# 2            Toptanci, I.; Ketenoglu, O.; Kiralan, M.
# 3   Chiang, Chow-Feng; Hsieh, Dennis PH; Hsu, Hui-...
# 4                 Sanchis, Y.; Coscolla, C.; Yusa, V.
# 5   Liu, X.; Guo, Z.; Krebs, K. A.; Pope, R. H.; R...
# 6   Vapenka, L.; Vavrous, A.; Votavova, L.; Kejlov...
# 7   Fengler, Romy; Schlummer, Martin; Wolz, Gerd; ...
# 8   Cesen, M.; Lambropoulou, D.; Laimou-Geraniou, ...
# 9                Moreta, Cristina; Tena, María Teresa
# 10  Zafeiraki, E.; Costopoulou, D.; Vassiliadou, I...
# 11                  Siao, P.; Tseng, S.H.; Chen, C.Y.
# 12                 Martinez-Moral, M. P.; Tena, M. T.
# 13      Poothong, S.; Boontanon, S. K.; Boontanon, N.
# 14  Surma, M.; Wiczkowski, W.; Zielinski, H.; Cies...
# 15  Lian, Lili; Jiang, Xinhao; Guan, Junjiao; Qiu,...
# 16  Schlummer, Martin; Sölch, Christina; Meisel, T...
# 17  Costopoulou, D.; Vassiliadou, I.; Zafeiraki, E...
# 18  Poothong, Somrutai; Boontanon, Suwanna Kitpati...
# 19  Zabaleta, I.; Bizkarguenaga, E.; Bilbao, D.; E...
# 20  Schaider, L. A.; Balan, S. A.; Blum, A.; Andre...
# 21  Zhang, S. J.; Sheng, C. C.; Zhang, J. C.; Li, ...
# 22  Tokranov, A. K.; Nishizawa, N.; Amadei, C. A.;...
# 23  Still, M.; Schlummer, M.; Gruber, L.; Fiedler,...
# 24  Siddique, Shabana; Zhang, Gong; Coleman, Kaela...
# 25  Lerch, Michaela; Nguyen, Khanh Hoang; Granby, Kit
# 26  Li, H.K.; Wu, X.F.; Wu, S.L.; Chen, L.C.; Kou,...
# 27  Vavrous, A.; Vapenka, L.; Sosnovcova, J.; Kejl...
# 28  Fengler, R; Schlummer, M; Gruber, L; Fiedler, ...
# 29  Begley, T. H.; Hsu, W.; Noonan, G.; Diachenko, G.
# 30               Xu, Y.; Noonan, G. O.; Begley, T. H.
# 31     Yang, Y.; Yu, J.; Yin, J.; Shao, B.; Zhang, J.
# 32  Han, Shuying; Song, Yilin; Hu, Jiachun; Liu, R...
# 33  Zabaleta, Itsaso; Blanco-Zubiaguirre, Laura; B...
# 34  Choi, H.; Bae, I. A.; Choi, J. C.; Park, S. J....
# 35  Kotthoff, M.; Muller, J.; Jurling, H.; Schlumm...
# 36  Begley, T. H.; White, K.; Honigfort, P.; Twaro...
# 37  Brenes, A. L. M.; Curtzwiler, G.; Dixon, P.; H...
# 38  Shoeib, Tamer; Hassan, Yasmeen; Rauert, Cassan...
# 39  Gebbink, W. A.; Ullah, S.; Sandblom, O.; Berge...
# 40  Zabaleta, Itsaso; Negreira, Noelia; Bizkarguen...
# 41  Chen, Y.; Lu, Z.; Huang, S.; Li, G.; Hu, Y.; Z...
# 42                          Sapozhnikova, Y.; Hoh, E.
# 43  Timshina, A.; Aristizabal-Henao, J. J.; Da Sil...
# 44                               Schultes, L.; et al.
# 45  Zhao, Nan; Zhu, Jianqiang; Zhao, Meirong; Jin,...
# 46              Yuan, G.; Peng, H.; Huang, C.; Hu, J.
#
#                                               Journal  Year  \
# 0                             Environmental Forensics  2020
# 1                         Journal of Chromatography B  2011
# 2        Environmental Science and Pollution Research  2022
# 3                   Journal of Food and Drug Analysis  2012
# 4                                             Talanta  2019
# 5                                         Chemosphere  2014
# 6              Journal of Food and Nutrition Research  2016
# 7                               Conference Proceeding  2012
# 8          Journal of agricultural and food chemistry  2016
# 9                         Journal of Chromatography A  2014
# 10                                        Chemosphere  2014
# 11                  Journal of Food and Drug Analysis  2022
# 12                                            Talanta  2012
# 13                     Journal of Hazardous Materials  2012
# 14                   Packaging Technology and Science  2015
# 15                        Journal of Chromatography A  2020
# 16                                        Chemosphere  2015
# 17                              Environmental Science  2013
# 18        Journal of Environmental Science and Health  2013
# 19                                            Talanta  2016
# 20         Environmental science & technology letters  2017
# 21                            Food Analytical Methods  2017
# 22       Environmental Science and Technology Letters  2019
# 23         Journal of agricultural and food chemistry  2013
# 24                   Current Research in Food Science  2021
# 25                                     Food Chemistry  2022
# 26                     Journal of Hazardous Materials  2022
# 27                                       Food Control  2016
# 28                                Organohalogen Compd  2011
# 29  Food additives & contaminants. Part A, Chemist...  2008
# 30  Food additives & contaminants. Part A, Chemist...  2013
# 31         Journal of agricultural and food chemistry  2014
# 32                                     Food Chemistry  2021
# 33                                     Food Chemistry  2020
# 34  Food additives & contaminants. Part B, Surveil...  2018
# 35  Environmental Science and Pollution Research I...  2015
# 36                    Food additives and contaminants  2005
# 37            Food Additives and Contaminants: Part B  2019
# 38                                        Chemosphere  2016
# 39       Environmental Science and Pollution Research  2013
# 40                                     Food Chemistry  2017
# 41                        Journal of Chromatography A  2022
# 42                              Chromatography Online  2019
# 43                                        Chemosphere  2021
# 44         Environmental science & technology letters  2019
# 45       Environmental Science and Pollution Research  2022
# 46                             Environ. Sci. Technol.  2016
#
#                                                   DOI
# 0       https://doi.org/10.1080/15275922.2020.1771631
# 1       https://doi.org/10.1016/j.jchromb.2011.05.032
# 2          https://doi.org/10.1007/s11356-022-18783-1
# 3   https://www.scopus.com/record/display.uri?eid=...
# 4       https://doi.org/10.1016/j.talanta.2018.08.047
# 5   https://doi.org/10.1016/j.chemosphere.2013.10.001
# 6    https://www.vup.sk/en/en/download.php?bulID=1914
# 7   https://www.researchgate.net/publication/23405...
# 8            https://doi.org/10.1021/acs.jafc.6b03924
# 9        https://doi.org/10.1016/j.chroma.2014.06.018
# 10  https://doi.org/10.1016/j.chemosphere.2013.09.092
# 11            https://doi.org/10.38212/2224-6614.3397
# 12      https://doi.org/10.1016/j.talanta.2012.09.007
# 13      https://doi.org/10.1016/j.jhazmat.2011.12.050
# 14                   https://doi.org/10.1002/pts.2140
# 15       https://doi.org/10.1016/j.chroma.2019.460666
# 16  https://doi.org/10.1016/j.chemosphere.2014.11.036
# 17  https://www.semanticscholar.org/paper/EXPOSURE...
# 18       https://doi.org/10.1080/03601234.2013.795838
# 19      https://doi.org/10.1016/j.talanta.2016.02.022
# 20        https://doi.org/10.1021/acs.estlett.6b00435
# 21          https://doi.org/10.1007/s12161-016-0660-x
# 22        https://doi.org/10.1021/acs.estlett.8b00600
# 23                  https://doi.org/10.1021/jf4020137
# 24         https://doi.org/10.1016/j.crfs.2021.08.006
# 25     https://doi.org/10.1016/j.foodchem.2022.133375
# 26      https://doi.org/10.1016/j.jhazmat.2022.129116
# 27     https://doi.org/10.1016/j.foodcont.2015.07.043
# 28  https://dev.dioxin20xx.org/wp-content/uploads/...
# 29          https://doi.org/10.1080/02652030701513784
# 30       https://doi.org/10.1080/19440049.2013.789556
# 31                  https://doi.org/10.1021/jf5037933
# 32     https://doi.org/10.1016/j.foodchem.2020.127766
# 33     https://doi.org/10.1016/j.foodchem.2020.126746
# 34      https://doi.org/10.1080/19393210.2018.1499677
# 35          https://doi.org/10.1007/s11356-015-4202-7
# 36          https://doi.org/10.1080/02652030500183474
# 37      https://doi.org/10.1080/19393210.2019.1592238
# 38  https://doi.org/10.1016/j.chemosphere.2015.08.066
# 39          https://doi.org/10.1007/s11356-013-1596-y
# 40     https://doi.org/10.1016/j.foodchem.2017.03.074
# 41       https://doi.org/10.1016/j.chroma.2022.462864
# 42  https://www.chromatographyonline.com/view/susp...
# 43  https://doi.org/10.1016/j.chemosphere.2021.130238
# 44        https://doi.org/10.1021/acs.estlett.8b00700
# 45         https://doi.org/10.1007/s11356-022-22890-4
# 46            https://doi.org/10.1021/acs.est.5b03806

# %%
def generate_endnote_txt_file(dataframe, output_file):
    """
    Generate an EndNote-compatible .txt file from a DataFrame.

    Parameters:
        dataframe (pd.DataFrame): Input DataFrame containing citation data.
        output_file (str): Path to the output .txt file.

    Returns:
        None
    """
    # Initialize the output string
    endnote_output = ""
    reference_number = 1  # Initialize the reference number

    for index, row in dataframe.iterrows():
        # Clean the DOI field by removing any extra rows
        doi = row['DOI'].strip('\n')

        # Construct the formatted line for the current entry
        formatted_line = (
            f'%0 Journal Article\n'  # Identifier for the reference type, FCCmigex is always journal article
                                     # More about reference types: https://libguides.utoledo.edu/c.php?g=284330&p=1895352
            f'%A {row["Authors"]}\n'
            f'%T {row["Title"]}\n'  # Article title
            f'%J {row["Journal"]}\n'  # Journal title
            f'%D {row["Year"]}\n'
            f'%R {doi}\n'
    #         f'%U \n'  # Add URL if available
    #         f'%K \n'  # Add keywords if available
    #         f'%X \n'  # Add abstract if available
    #         f'%N \n'  # Add any additional notes
        )

        # Append the formatted line to the output string
        endnote_output += formatted_line + '\n'

    # Write the formatted EndNote entries to a .txt file
    with open(output_file, 'w', encoding='utf-8-sig') as f:
        f.write(endnote_output)

# %%
# Usage example
#generate_endnote_txt_file(PFAS_excel, '2023_PFASpaper_47references.txt')
